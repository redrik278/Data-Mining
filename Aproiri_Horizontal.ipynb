# %% [markdown]
# #Chess

# %%
import time
import matplotlib.pyplot as plt

class Pattern:
    def __init__(self, itemset, support):
        self.itemset = itemset
        self.support = support

def has_infrequent_subset(c, Lk_minus_1):
    for i in range(len(c)):
        subset = c[:i] + c[i+1:]
        if subset not in Lk_minus_1:
            return True
    return False

def apriori_gen(Lk_minus_1):
    Ck = []
    for i in range(len(Lk_minus_1)):
        for j in range(i+1, len(Lk_minus_1)):
            l1 = Lk_minus_1[i]
            l2 = Lk_minus_1[j]
            if l1[:-1] == l2[:-1] and l1[-1] < l2[-1]:
                c = l1 + [l2[-1]]
                if not has_infrequent_subset(c, Lk_minus_1):
                    Ck.append(c)
    return Ck

def apriori(D, min_sup):
    L = []
    Lk_minus_1 = []
    Ck = []

    for item in D:
        for i in item:
            if [i] not in Ck:
                Ck.append([i])

    k = 1
    total_time = 0
    while Ck:
        Lk_minus_1 = Ck
        Lk = []

        start_time = time.time()  # Start timing
        for c in Ck:
            count = 0
            for t in D:
                if set(c).issubset(t):
                    count += 1
            if count >= min_sup:
                itemset = c
                support = count
                pattern = Pattern(itemset, support)
                Lk.append(pattern)
                print(f"Minimum_support: {min_sup}-Frequent {k}-itemset: {pattern.itemset} - support {pattern.support}")
        end_time = time.time()  # End timing
        iteration_time = end_time - start_time
        total_time += iteration_time

        L.extend(Lk)
        k += 1
        Ck = apriori_gen(Lk_minus_1)

    return L, total_time

def main():
    path = "/content/drive/MyDrive/Colab Notebooks/477/mushroom.dat"
    D = [] #transaction
    with open(path, "r") as ftpr:
        for line in ftpr:
            tokens = line.strip().split()
            tokens.sort()
            D.append(tokens)

    min_sup_percentages = [50, 79]
    total_times = []

    for min_sup_percentage in min_sup_percentages:
        min_sup = int(min_sup_percentage * len(D) / 100)
        frequent_itemsets, total_time = apriori(D, min_sup)
        total_times.append(total_time)

        print(f"Total Time taken for Min Sup {min_sup_percentage}%: {total_time:.4f} seconds\n")

    # Create bar plot
    plt.bar(min_sup_percentages, total_times, align='center')
    plt.xlabel("Minimum Support Percentage")
    plt.ylabel("Total Time (seconds)")
    plt.title("Total Time Taken for Different Minimum Support Percentages")
    plt.xticks(min_sup_percentages)
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Minimum_support: 4062-Frequent 1-itemset: ['34'] - support 7914
# Minimum_support: 4062-Frequent 1-itemset: ['36'] - support 6812
# Minimum_support: 4062-Frequent 1-itemset: ['59'] - support 5176
# Minimum_support: 4062-Frequent 1-itemset: ['63'] - support 4936
# Minimum_support: 4062-Frequent 1-itemset: ['67'] - support 4464
# Minimum_support: 4062-Frequent 1-itemset: ['76'] - support 4384
# Minimum_support: 4062-Frequent 1-itemset: ['85'] - support 8124
# Minimum_support: 4062-Frequent 1-itemset: ['86'] - support 7924
# Minimum_support: 4062-Frequent 1-itemset: ['90'] - support 7488
# Minimum_support: 4062-Frequent 1-itemset: ['2'] - support 4208
# Minimum_support: 4062-Frequent 1-itemset: ['39'] - support 5612
# Minimum_support: 4062-Frequent 1-itemset: ['24'] - support 4748
# Minimum_support: 4062-Frequent 1-itemset: ['53'] - support 4608
# Minimum_support: 4062-Frequent 2-itemset: ['34', '36'] - support 6602
# Minimum_support: 4062-Frequent 2-itemset: ['34', '59'] - support 4984
# Minimum_support: 4062-Frequent 2-itemset: ['34', '63'] - support 4744
# Minimum_support: 4062-Frequent 2-itemset: ['34', '67'] - support 4464
# Minimum_support: 4062-Frequent 2-itemset: ['34', '76'] - support 4384
# Minimum_support: 4062-Frequent 2-itemset: ['34', '85'] - support 7914
# Minimum_support: 4062-Frequent 2-itemset: ['34', '86'] - support 7906
# Minimum_support: 4062-Frequent 2-itemset: ['34', '90'] - support 7296
# Minimum_support: 4062-Frequent 2-itemset: ['34', '39'] - support 5402
# Minimum_support: 4062-Frequent 2-itemset: ['34', '53'] - support 4608
# Minimum_support: 4062-Frequent 2-itemset: ['36', '59'] - support 4424
# Minimum_support: 4062-Frequent 2-itemset: ['36', '63'] - support 4184
# Minimum_support: 4062-Frequent 2-itemset: ['36', '85'] - support 6812
# Minimum_support: 4062-Frequent 2-itemset: ['36', '86'] - support 6620
# Minimum_support: 4062-Frequent 2-itemset: ['36', '90'] - support 6464
# Minimum_support: 4062-Frequent 2-itemset: ['36', '39'] - support 4556
# Minimum_support: 4062-Frequent 2-itemset: ['59', '63'] - support 4156
# Minimum_support: 4062-Frequent 2-itemset: ['59', '85'] - support 5176
# Minimum_support: 4062-Frequent 2-itemset: ['59', '86'] - support 4984
# Minimum_support: 4062-Frequent 2-itemset: ['59', '90'] - support 4736
# Minimum_support: 4062-Frequent 2-itemset: ['63', '85'] - support 4936
# Minimum_support: 4062-Frequent 2-itemset: ['63', '86'] - support 4744
# Minimum_support: 4062-Frequent 2-itemset: ['63', '90'] - support 4496
# Minimum_support: 4062-Frequent 2-itemset: ['67', '85'] - support 4464
# Minimum_support: 4062-Frequent 2-itemset: ['67', '86'] - support 4464
# Minimum_support: 4062-Frequent 2-itemset: ['76', '85'] - support 4384
# Minimum_support: 4062-Frequent 2-itemset: ['76', '86'] - support 4384
# Minimum_support: 4062-Frequent 2-itemset: ['85', '86'] - support 7924
# Minimum_support: 4062-Frequent 2-itemset: ['85', '90'] - support 7488
# Minimum_support: 4062-Frequent 2-itemset: ['86', '90'] - support 7288
# Minimum_support: 4062-Frequent 3-itemset: ['34', '36', '59'] - support 4232
# Minimum_support: 4062-Frequent 3-itemset: ['34', '36', '85'] - support 6602
# Minimum_support: 4062-Frequent 3-itemset: ['34', '36', '86'] - support 6602
# Minimum_support: 4062-Frequent 3-itemset: ['34', '36', '90'] - support 6272
# Minimum_support: 4062-Frequent 3-itemset: ['34', '36', '39'] - support 4346
# Minimum_support: 4062-Frequent 3-itemset: ['34', '59', '85'] - support 4984
# Minimum_support: 4062-Frequent 3-itemset: ['34', '59', '86'] - support 4984
# Minimum_support: 4062-Frequent 3-itemset: ['34', '59', '90'] - support 4544
# Minimum_support: 4062-Frequent 3-itemset: ['34', '63', '85'] - support 4744
# Minimum_support: 4062-Frequent 3-itemset: ['34', '63', '86'] - support 4744
# Minimum_support: 4062-Frequent 3-itemset: ['34', '63', '90'] - support 4304
# Minimum_support: 4062-Frequent 3-itemset: ['34', '67', '85'] - support 4464
# Minimum_support: 4062-Frequent 3-itemset: ['34', '67', '86'] - support 4464
# Minimum_support: 4062-Frequent 3-itemset: ['34', '76', '85'] - support 4384
# Minimum_support: 4062-Frequent 3-itemset: ['34', '76', '86'] - support 4384
# Minimum_support: 4062-Frequent 3-itemset: ['34', '85', '86'] - support 7906
# Minimum_support: 4062-Frequent 3-itemset: ['34', '85', '90'] - support 7296
# Minimum_support: 4062-Frequent 3-itemset: ['34', '86', '90'] - support 7288
# Minimum_support: 4062-Frequent 3-itemset: ['36', '59', '85'] - support 4424
# Minimum_support: 4062-Frequent 3-itemset: ['36', '59', '86'] - support 4232
# Minimum_support: 4062-Frequent 3-itemset: ['36', '59', '90'] - support 4128
# Minimum_support: 4062-Frequent 3-itemset: ['36', '63', '85'] - support 4184
# Minimum_support: 4062-Frequent 3-itemset: ['36', '85', '86'] - support 6620
# Minimum_support: 4062-Frequent 3-itemset: ['36', '85', '90'] - support 6464
# Minimum_support: 4062-Frequent 3-itemset: ['36', '86', '90'] - support 6272
# Minimum_support: 4062-Frequent 3-itemset: ['59', '63', '85'] - support 4156
# Minimum_support: 4062-Frequent 3-itemset: ['59', '85', '86'] - support 4984
# Minimum_support: 4062-Frequent 3-itemset: ['59', '85', '90'] - support 4736
# Minimum_support: 4062-Frequent 3-itemset: ['59', '86', '90'] - support 4544
# Minimum_support: 4062-Frequent 3-itemset: ['63', '85', '86'] - support 4744
# Minimum_support: 4062-Frequent 3-itemset: ['63', '85', '90'] - support 4496
# Minimum_support: 4062-Frequent 3-itemset: ['63', '86', '90'] - support 4304
# Minimum_support: 4062-Frequent 3-itemset: ['67', '85', '86'] - support 4464
# Minimum_support: 4062-Frequent 3-itemset: ['76', '85', '86'] - support 4384
# Minimum_support: 4062-Frequent 3-itemset: ['85', '86', '90'] - support 7288
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-ad6df2d163da> in <cell line: 93>()
#      92
#      93 if __name__ == "__main__":
# ---> 94     main()
#
# <ipython-input-2-ad6df2d163da> in main()
#      78     for min_sup_percentage in min_sup_percentages:
#      79         min_sup = int(min_sup_percentage * len(D) / 100)
# ---> 80         frequent_itemsets, total_time = apriori(D, min_sup)
#      81         total_times.append(total_time)
#      82
#
# <ipython-input-2-ad6df2d163da> in apriori(D, min_sup)
#      60         L.extend(Lk)
#      61         k += 1
# ---> 62         Ck = apriori_gen(Lk_minus_1)
#      63
#      64     return L, total_time
#
# <ipython-input-2-ad6df2d163da> in apriori_gen(Lk_minus_1)
#      20             l1 = Lk_minus_1[i]
#      21             l2 = Lk_minus_1[j]
# ---> 22             if l1[:-1] == l2[:-1] and l1[-1] < l2[-1]:
#      23                 c = l1 + [l2[-1]]
#      24                 if not has_infrequent_subset(c, Lk_minus_1):
#
# KeyboardInterrupt:

# %% [markdown]
# # Mushroom

# %%
import time
import matplotlib.pyplot as plt

class Pattern:
    def __init__(self, itemset, support):
        self.itemset = itemset
        self.support = support

def has_infrequent_subset(c, Lk_minus_1):
    for i in range(len(c)):
        subset = tuple(c[:i] + c[i+1:])
        if subset not in Lk_minus_1:
            return True
    return False

def apriori_gen(Lk_minus_1):
    Ck = {}
    for i in range(len(Lk_minus_1)):
        for j in range(i+1, len(Lk_minus_1)):
            l1 = Lk_minus_1[i]
            l2 = Lk_minus_1[j]
            if l1[:-1] == l2[:-1] and l1[-1] < l2[-1]:
                c = l1 + (l2[-1],)
                if not has_infrequent_subset(c, Lk_minus_1):
                    Ck[c] = 0
    return Ck

def apriori(D, min_sup):
    L = {}
    Lk_minus_1 = {}
    Ck = {}

    for item in D:
        for i in item:
            Ck[(i,)] = Ck.get((i,), 0) + 1

    k = 1
    total_time = 0
    while Ck:
        Lk_minus_1 = Ck
        Lk = {}

        start_time = time.time()  # Start timing
        for c in Ck.keys():
            count = 0
            for t in D:
                if set(c).issubset(t):
                    count += 1
            if count >= min_sup:
                Lk[c] = count
                pattern = Pattern(c, count)
                print(f"Minimum_support: {min_sup}-Frequent {k}-itemset: {pattern.itemset} - support {pattern.support}")
        end_time = time.time()  # End timing
        iteration_time = end_time - start_time
        total_time += iteration_time

        L.update(Lk)
        k += 1
        Ck = apriori_gen(list(Lk.keys()))

    return L, total_time

def main():
    path = "/content/drive/MyDrive/Colab Notebooks/477/mushroom.dat"
    D = [] #transaction
    with open(path, "r") as ftpr:
        for line in ftpr:
            tokens = line.strip().split()
            tokens.sort()
            D.append(tokens)

    min_sup_percentages = [50, 60, 70,80,90]
    total_times = []

    for min_sup_percentage in min_sup_percentages:
        min_sup = int(min_sup_percentage * len(D) / 100)
        frequent_itemsets, total_time = apriori(D, min_sup)
        total_times.append(total_time)

        print(f"Total Time taken for Min Sup {min_sup_percentage}%: {total_time:.4f} seconds\n")

    # Create bar plot
    plt.bar(min_sup_percentages, total_times, align='center')
    plt.xlabel("Minimum Support Percentage")
    plt.ylabel("Total Time (seconds)")
    plt.title("Total Time Taken for Different Minimum Support Percentages")
    plt.xticks(min_sup_percentages)
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Minimum_support: 4062-Frequent 1-itemset: ('34',) - support 7914
# Minimum_support: 4062-Frequent 1-itemset: ('36',) - support 6812
# Minimum_support: 4062-Frequent 1-itemset: ('59',) - support 5176
# Minimum_support: 4062-Frequent 1-itemset: ('63',) - support 4936
# Minimum_support: 4062-Frequent 1-itemset: ('67',) - support 4464
# Minimum_support: 4062-Frequent 1-itemset: ('76',) - support 4384
# Minimum_support: 4062-Frequent 1-itemset: ('85',) - support 8124
# Minimum_support: 4062-Frequent 1-itemset: ('86',) - support 7924
# Minimum_support: 4062-Frequent 1-itemset: ('90',) - support 7488
# Minimum_support: 4062-Frequent 1-itemset: ('2',) - support 4208
# Minimum_support: 4062-Frequent 1-itemset: ('39',) - support 5612
# Minimum_support: 4062-Frequent 1-itemset: ('24',) - support 4748
# Minimum_support: 4062-Frequent 1-itemset: ('53',) - support 4608
# Minimum_support: 4062-Frequent 2-itemset: ('34', '36') - support 6602
# Minimum_support: 4062-Frequent 2-itemset: ('34', '59') - support 4984
# Minimum_support: 4062-Frequent 2-itemset: ('34', '63') - support 4744
# Minimum_support: 4062-Frequent 2-itemset: ('34', '67') - support 4464
# Minimum_support: 4062-Frequent 2-itemset: ('34', '76') - support 4384
# Minimum_support: 4062-Frequent 2-itemset: ('34', '85') - support 7914
# Minimum_support: 4062-Frequent 2-itemset: ('34', '86') - support 7906
# Minimum_support: 4062-Frequent 2-itemset: ('34', '90') - support 7296
# Minimum_support: 4062-Frequent 2-itemset: ('34', '39') - support 5402
# Minimum_support: 4062-Frequent 2-itemset: ('34', '53') - support 4608
# Minimum_support: 4062-Frequent 2-itemset: ('36', '59') - support 4424
# Minimum_support: 4062-Frequent 2-itemset: ('36', '63') - support 4184
# Minimum_support: 4062-Frequent 2-itemset: ('36', '85') - support 6812
# Minimum_support: 4062-Frequent 2-itemset: ('36', '86') - support 6620
# Minimum_support: 4062-Frequent 2-itemset: ('36', '90') - support 6464
# Minimum_support: 4062-Frequent 2-itemset: ('36', '39') - support 4556
# Minimum_support: 4062-Frequent 2-itemset: ('59', '63') - support 4156
# Minimum_support: 4062-Frequent 2-itemset: ('59', '85') - support 5176
# Minimum_support: 4062-Frequent 2-itemset: ('59', '86') - support 4984
# Minimum_support: 4062-Frequent 2-itemset: ('59', '90') - support 4736
# Minimum_support: 4062-Frequent 2-itemset: ('63', '85') - support 4936
# Minimum_support: 4062-Frequent 2-itemset: ('63', '86') - support 4744
# Minimum_support: 4062-Frequent 2-itemset: ('63', '90') - support 4496
# Minimum_support: 4062-Frequent 2-itemset: ('67', '85') - support 4464
# Minimum_support: 4062-Frequent 2-itemset: ('67', '86') - support 4464
# Minimum_support: 4062-Frequent 2-itemset: ('76', '85') - support 4384
# Minimum_support: 4062-Frequent 2-itemset: ('76', '86') - support 4384
# Minimum_support: 4062-Frequent 2-itemset: ('85', '86') - support 7924
# Minimum_support: 4062-Frequent 2-itemset: ('85', '90') - support 7488
# Minimum_support: 4062-Frequent 2-itemset: ('86', '90') - support 7288
# Minimum_support: 4062-Frequent 3-itemset: ('34', '36', '59') - support 4232
# Minimum_support: 4062-Frequent 3-itemset: ('34', '36', '85') - support 6602
# Minimum_support: 4062-Frequent 3-itemset: ('34', '36', '86') - support 6602
# Minimum_support: 4062-Frequent 3-itemset: ('34', '36', '90') - support 6272
# Minimum_support: 4062-Frequent 3-itemset: ('34', '36', '39') - support 4346
# Minimum_support: 4062-Frequent 3-itemset: ('34', '59', '85') - support 4984
# Minimum_support: 4062-Frequent 3-itemset: ('34', '59', '86') - support 4984
# Minimum_support: 4062-Frequent 3-itemset: ('34', '59', '90') - support 4544
# Minimum_support: 4062-Frequent 3-itemset: ('34', '63', '85') - support 4744
# Minimum_support: 4062-Frequent 3-itemset: ('34', '63', '86') - support 4744
# Minimum_support: 4062-Frequent 3-itemset: ('34', '63', '90') - support 4304
# Minimum_support: 4062-Frequent 3-itemset: ('34', '67', '85') - support 4464
# Minimum_support: 4062-Frequent 3-itemset: ('34', '67', '86') - support 4464
# Minimum_support: 4062-Frequent 3-itemset: ('34', '76', '85') - support 4384
# Minimum_support: 4062-Frequent 3-itemset: ('34', '76', '86') - support 4384
# Minimum_support: 4062-Frequent 3-itemset: ('34', '85', '86') - support 7906
# Minimum_support: 4062-Frequent 3-itemset: ('34', '85', '90') - support 7296
# Minimum_support: 4062-Frequent 3-itemset: ('34', '86', '90') - support 7288
# Minimum_support: 4062-Frequent 3-itemset: ('36', '59', '85') - support 4424
# Minimum_support: 4062-Frequent 3-itemset: ('36', '59', '86') - support 4232
# Minimum_support: 4062-Frequent 3-itemset: ('36', '59', '90') - support 4128
# Minimum_support: 4062-Frequent 3-itemset: ('36', '63', '85') - support 4184
# Minimum_support: 4062-Frequent 3-itemset: ('36', '85', '86') - support 6620
# Minimum_support: 4062-Frequent 3-itemset: ('36', '85', '90') - support 6464
# Minimum_support: 4062-Frequent 3-itemset: ('36', '86', '90') - support 6272
# Minimum_support: 4062-Frequent 3-itemset: ('59', '63', '85') - support 4156
# Minimum_support: 4062-Frequent 3-itemset: ('59', '85', '86') - support 4984
# Minimum_support: 4062-Frequent 3-itemset: ('59', '85', '90') - support 4736
# Minimum_support: 4062-Frequent 3-itemset: ('59', '86', '90') - support 4544
# Minimum_support: 4062-Frequent 3-itemset: ('63', '85', '86') - support 4744
# Minimum_support: 4062-Frequent 3-itemset: ('63', '85', '90') - support 4496
# Minimum_support: 4062-Frequent 3-itemset: ('63', '86', '90') - support 4304
# Minimum_support: 4062-Frequent 3-itemset: ('67', '85', '86') - support 4464
# Minimum_support: 4062-Frequent 3-itemset: ('76', '85', '86') - support 4384
# Minimum_support: 4062-Frequent 3-itemset: ('85', '86', '90') - support 7288
# Minimum_support: 4062-Frequent 4-itemset: ('34', '36', '59', '85') - support 4232
# Minimum_support: 4062-Frequent 4-itemset: ('34', '36', '59', '86') - support 4232
# Minimum_support: 4062-Frequent 4-itemset: ('34', '36', '85', '86') - support 6602
# Minimum_support: 4062-Frequent 4-itemset: ('34', '36', '85', '90') - support 6272
# Minimum_support: 4062-Frequent 4-itemset: ('34', '36', '86', '90') - support 6272
# Minimum_support: 4062-Frequent 4-itemset: ('34', '59', '85', '86') - support 4984
# Minimum_support: 4062-Frequent 4-itemset: ('34', '59', '85', '90') - support 4544
# Minimum_support: 4062-Frequent 4-itemset: ('34', '59', '86', '90') - support 4544
# Minimum_support: 4062-Frequent 4-itemset: ('34', '63', '85', '86') - support 4744
# Minimum_support: 4062-Frequent 4-itemset: ('34', '63', '85', '90') - support 4304
# Minimum_support: 4062-Frequent 4-itemset: ('34', '63', '86', '90') - support 4304
# Minimum_support: 4062-Frequent 4-itemset: ('34', '67', '85', '86') - support 4464
# Minimum_support: 4062-Frequent 4-itemset: ('34', '76', '85', '86') - support 4384
# Minimum_support: 4062-Frequent 4-itemset: ('34', '85', '86', '90') - support 7288
# Minimum_support: 4062-Frequent 4-itemset: ('36', '59', '85', '86') - support 4232
# Minimum_support: 4062-Frequent 4-itemset: ('36', '59', '85', '90') - support 4128
# Minimum_support: 4062-Frequent 4-itemset: ('36', '85', '86', '90') - support 6272
# Minimum_support: 4062-Frequent 4-itemset: ('59', '85', '86', '90') - support 4544
# Minimum_support: 4062-Frequent 4-itemset: ('63', '85', '86', '90') - support 4304
# Minimum_support: 4062-Frequent 5-itemset: ('34', '36', '59', '85', '86') - support 4232
# Minimum_support: 4062-Frequent 5-itemset: ('34', '36', '85', '86', '90') - support 6272
# Minimum_support: 4062-Frequent 5-itemset: ('34', '59', '85', '86', '90') - support 4544
# Minimum_support: 4062-Frequent 5-itemset: ('34', '63', '85', '86', '90') - support 4304
# Total Time taken for Min Sup 50%: 2.9961 seconds
#
# Minimum_support: 4874-Frequent 1-itemset: ('34',) - support 7914
# Minimum_support: 4874-Frequent 1-itemset: ('36',) - support 6812
# Minimum_support: 4874-Frequent 1-itemset: ('59',) - support 5176
# Minimum_support: 4874-Frequent 1-itemset: ('63',) - support 4936
# Minimum_support: 4874-Frequent 1-itemset: ('85',) - support 8124
# Minimum_support: 4874-Frequent 1-itemset: ('86',) - support 7924
# Minimum_support: 4874-Frequent 1-itemset: ('90',) - support 7488
# Minimum_support: 4874-Frequent 1-itemset: ('39',) - support 5612
# Minimum_support: 4874-Frequent 2-itemset: ('34', '36') - support 6602
# Minimum_support: 4874-Frequent 2-itemset: ('34', '59') - support 4984
# Minimum_support: 4874-Frequent 2-itemset: ('34', '85') - support 7914
# Minimum_support: 4874-Frequent 2-itemset: ('34', '86') - support 7906
# Minimum_support: 4874-Frequent 2-itemset: ('34', '90') - support 7296
# Minimum_support: 4874-Frequent 2-itemset: ('34', '39') - support 5402
# Minimum_support: 4874-Frequent 2-itemset: ('36', '85') - support 6812
# Minimum_support: 4874-Frequent 2-itemset: ('36', '86') - support 6620
# Minimum_support: 4874-Frequent 2-itemset: ('36', '90') - support 6464
# Minimum_support: 4874-Frequent 2-itemset: ('59', '85') - support 5176
# Minimum_support: 4874-Frequent 2-itemset: ('59', '86') - support 4984
# Minimum_support: 4874-Frequent 2-itemset: ('63', '85') - support 4936
# Minimum_support: 4874-Frequent 2-itemset: ('85', '86') - support 7924
# Minimum_support: 4874-Frequent 2-itemset: ('85', '90') - support 7488
# Minimum_support: 4874-Frequent 2-itemset: ('86', '90') - support 7288
# Minimum_support: 4874-Frequent 3-itemset: ('34', '36', '85') - support 6602
# Minimum_support: 4874-Frequent 3-itemset: ('34', '36', '86') - support 6602
# Minimum_support: 4874-Frequent 3-itemset: ('34', '36', '90') - support 6272
# Minimum_support: 4874-Frequent 3-itemset: ('34', '59', '85') - support 4984
# Minimum_support: 4874-Frequent 3-itemset: ('34', '59', '86') - support 4984
# Minimum_support: 4874-Frequent 3-itemset: ('34', '85', '86') - support 7906
# Minimum_support: 4874-Frequent 3-itemset: ('34', '85', '90') - support 7296
# Minimum_support: 4874-Frequent 3-itemset: ('34', '86', '90') - support 7288
# Minimum_support: 4874-Frequent 3-itemset: ('36', '85', '86') - support 6620
# Minimum_support: 4874-Frequent 3-itemset: ('36', '85', '90') - support 6464
# Minimum_support: 4874-Frequent 3-itemset: ('36', '86', '90') - support 6272
# Minimum_support: 4874-Frequent 3-itemset: ('59', '85', '86') - support 4984
# Minimum_support: 4874-Frequent 3-itemset: ('85', '86', '90') - support 7288
# Minimum_support: 4874-Frequent 4-itemset: ('34', '36', '85', '86') - support 6602
# Minimum_support: 4874-Frequent 4-itemset: ('34', '36', '85', '90') - support 6272
# Minimum_support: 4874-Frequent 4-itemset: ('34', '36', '86', '90') - support 6272
# Minimum_support: 4874-Frequent 4-itemset: ('34', '59', '85', '86') - support 4984
# Minimum_support: 4874-Frequent 4-itemset: ('34', '85', '86', '90') - support 7288
# Minimum_support: 4874-Frequent 4-itemset: ('36', '85', '86', '90') - support 6272
# Minimum_support: 4874-Frequent 5-itemset: ('34', '36', '85', '86', '90') - support 6272
# Total Time taken for Min Sup 60%: 2.0316 seconds
#
# Minimum_support: 5686-Frequent 1-itemset: ('34',) - support 7914
# Minimum_support: 5686-Frequent 1-itemset: ('36',) - support 6812
# Minimum_support: 5686-Frequent 1-itemset: ('85',) - support 8124
# Minimum_support: 5686-Frequent 1-itemset: ('86',) - support 7924
# Minimum_support: 5686-Frequent 1-itemset: ('90',) - support 7488
# Minimum_support: 5686-Frequent 2-itemset: ('34', '36') - support 6602
# Minimum_support: 5686-Frequent 2-itemset: ('34', '85') - support 7914
# Minimum_support: 5686-Frequent 2-itemset: ('34', '86') - support 7906
# Minimum_support: 5686-Frequent 2-itemset: ('34', '90') - support 7296
# Minimum_support: 5686-Frequent 2-itemset: ('36', '85') - support 6812
# Minimum_support: 5686-Frequent 2-itemset: ('36', '86') - support 6620
# Minimum_support: 5686-Frequent 2-itemset: ('36', '90') - support 6464
# Minimum_support: 5686-Frequent 2-itemset: ('85', '86') - support 7924
# Minimum_support: 5686-Frequent 2-itemset: ('85', '90') - support 7488
# Minimum_support: 5686-Frequent 2-itemset: ('86', '90') - support 7288
# Minimum_support: 5686-Frequent 3-itemset: ('34', '36', '85') - support 6602
# Minimum_support: 5686-Frequent 3-itemset: ('34', '36', '86') - support 6602
# Minimum_support: 5686-Frequent 3-itemset: ('34', '36', '90') - support 6272
# Minimum_support: 5686-Frequent 3-itemset: ('34', '85', '86') - support 7906
# Minimum_support: 5686-Frequent 3-itemset: ('34', '85', '90') - support 7296
# Minimum_support: 5686-Frequent 3-itemset: ('34', '86', '90') - support 7288
# Minimum_support: 5686-Frequent 3-itemset: ('36', '85', '86') - support 6620
# Minimum_support: 5686-Frequent 3-itemset: ('36', '85', '90') - support 6464
# Minimum_support: 5686-Frequent 3-itemset: ('36', '86', '90') - support 6272
# Minimum_support: 5686-Frequent 3-itemset: ('85', '86', '90') - support 7288
# Minimum_support: 5686-Frequent 4-itemset: ('34', '36', '85', '86') - support 6602
# Minimum_support: 5686-Frequent 4-itemset: ('34', '36', '85', '90') - support 6272
# Minimum_support: 5686-Frequent 4-itemset: ('34', '36', '86', '90') - support 6272
# Minimum_support: 5686-Frequent 4-itemset: ('34', '85', '86', '90') - support 7288
# Minimum_support: 5686-Frequent 4-itemset: ('36', '85', '86', '90') - support 6272
# Minimum_support: 5686-Frequent 5-itemset: ('34', '36', '85', '86', '90') - support 6272
# Total Time taken for Min Sup 70%: 2.5097 seconds
#
# Minimum_support: 6499-Frequent 1-itemset: ('34',) - support 7914
# Minimum_support: 6499-Frequent 1-itemset: ('36',) - support 6812
# Minimum_support: 6499-Frequent 1-itemset: ('85',) - support 8124
# Minimum_support: 6499-Frequent 1-itemset: ('86',) - support 7924
# Minimum_support: 6499-Frequent 1-itemset: ('90',) - support 7488
# Minimum_support: 6499-Frequent 2-itemset: ('34', '36') - support 6602
# Minimum_support: 6499-Frequent 2-itemset: ('34', '85') - support 7914
# Minimum_support: 6499-Frequent 2-itemset: ('34', '86') - support 7906
# Minimum_support: 6499-Frequent 2-itemset: ('34', '90') - support 7296
# Minimum_support: 6499-Frequent 2-itemset: ('36', '85') - support 6812
# Minimum_support: 6499-Frequent 2-itemset: ('36', '86') - support 6620
# Minimum_support: 6499-Frequent 2-itemset: ('85', '86') - support 7924
# Minimum_support: 6499-Frequent 2-itemset: ('85', '90') - support 7488
# Minimum_support: 6499-Frequent 2-itemset: ('86', '90') - support 7288
# Minimum_support: 6499-Frequent 3-itemset: ('34', '36', '85') - support 6602
# Minimum_support: 6499-Frequent 3-itemset: ('34', '36', '86') - support 6602
# Minimum_support: 6499-Frequent 3-itemset: ('34', '85', '86') - support 7906
# Minimum_support: 6499-Frequent 3-itemset: ('34', '85', '90') - support 7296
# Minimum_support: 6499-Frequent 3-itemset: ('34', '86', '90') - support 7288
# Minimum_support: 6499-Frequent 3-itemset: ('36', '85', '86') - support 6620
# Minimum_support: 6499-Frequent 3-itemset: ('85', '86', '90') - support 7288
# Minimum_support: 6499-Frequent 4-itemset: ('34', '36', '85', '86') - support 6602
# Minimum_support: 6499-Frequent 4-itemset: ('34', '85', '86', '90') - support 7288
# Total Time taken for Min Sup 80%: 2.5217 seconds
#
# Minimum_support: 7311-Frequent 1-itemset: ('34',) - support 7914
# Minimum_support: 7311-Frequent 1-itemset: ('85',) - support 8124
# Minimum_support: 7311-Frequent 1-itemset: ('86',) - support 7924
# Minimum_support: 7311-Frequent 1-itemset: ('90',) - support 7488
# Minimum_support: 7311-Frequent 2-itemset: ('34', '85') - support 7914
# Minimum_support: 7311-Frequent 2-itemset: ('34', '86') - support 7906
# Minimum_support: 7311-Frequent 2-itemset: ('85', '86') - support 7924
# Minimum_support: 7311-Frequent 2-itemset: ('85', '90') - support 7488
# Minimum_support: 7311-Frequent 3-itemset: ('34', '85', '86') - support 7906
# Total Time taken for Min Sup 90%: 1.5253 seconds
